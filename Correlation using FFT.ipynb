# %%
# %matplotlib inline

# %%
from pylab import * 
from  scipy.signal import correlate as correlate1

# %%
x = randn(100)
y = randn(100)

# %%
plot(correlate1(x,x))

# %%
plot(correlate1(x,y))

# %%
import scipy.fftpack as fftp

# %%
def pad(ar):
    l  = len(ar)
    z = zeros(l)
    a = array((ar, z))
    a = a.reshape((l*2))
    return a

# %% [markdown]
# Fourrier based correlation
# ===============
# using:
# $${\rm corr}\left(x,y\right)\left(t\right)=\mathcal{F}^{-1}\left\{ \mathcal{F}\left[x\right]\left(\omega\right)\mathcal{F}\left[y\right]\left(-\omega\right)\right\} $$

# %%
def correlate_fft(x,y):
    return fftp.ifft(fftp.fft(pad(x)) * fftp.fft(pad(y[::-1])) )

# %%
plot(correlate_fft(x,x))
plot(correlate1(x,x),".")
# Out:
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plot(correlate_fft(x,y)) 
plot(correlate1(x,y),".")

# %%
x = arange(0,100)
y = sin(x)**2 - x**3

# %%
plot(correlate_fft(x,x))
plot(correlate1(x,x),".")

# %%
plot(correlate_fft(x,y)) 
plot(correlate1(x,y),".")
