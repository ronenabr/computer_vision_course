# %%
from numpy import *
from pylab import * 
import cv2
import os
import scipy.signal
# %matplotlib inline

# %%
opencv_examples = "/home/ronen/temp/opencv-2.4.10/samples/c/"

# %%
def gauss_filter(sigma, ker_size = None):
    if not ker_size:
        ker_size = int(sigma*5)
        if (ker_size%2):
            ker_size += 1
    gauss = lambda (x,y) : exp(-(x**2+y**2)/(2*sigma**2))
    X,Y = meshgrid(arange(-(ker_size/2),ker_size/2+1),arange(-(ker_size/2),ker_size/2+1))
    return  gauss((X,Y))

# %%
imshow( gauss_filter(30))

# %%
img1 = cv2.imread(os.path.join(opencv_examples,"box.png"),0)[:75,:75]
imshow(img1, cmap='gray')

# %%
def make_odd(i):
    if i%2 == 0:
        return i+1
    return i

def computer_kerr_size(sigmas):
    sigma = max(array(sigmas))
    return make_odd(int(sigma*5))

# %%
def L(I, sigma1, sigma2=None, ker_size=None) :
    if not sigma2:
        sigma2 = sqrt(2) * sigma1
    if not ker_size:
        ker_size = computer_kerr_size([sigma1, sigma2])
    
    return scipy.signal.convolve2d(I, 
            (gauss_filter(sigma2,ker_size)-gauss_filter(sigma1,ker_size))/((sqrt(2)-1)*sigma1**2))

def L2(I, sigma1, sigma2=None) :
    if not sigma2:
        sigma2 = sqrt(2) * sigma1
    ker_size = make_odd(int(sigma2*5))
    return scipy.signal.convolve2d(I, 
            gauss_filter(sigma2,ker_size))  - scipy.signal.convolve2d(I, 
            gauss_filter(sigma1,ker_size))

# %%
figure(figsize=(10,10))
imshow(L(img1,3), cmap='gray')
figure(figsize=(10,10))
imshow(L2(img1,3), cmap='gray')
figure(figsize=(10,10))

imshow(L2(img1,3)-L(img1,3), cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f6052f063f8>

# %%
img1.shape
# Out:
# (75, 75)

# %%
L(img1,5).shape
# Out:
# (109, 109)

# %%
sq2 = sqrt(2)
sigmas = sq2**arange(0,5) 
print sigmas
ker_size = computer_kerr_size(sigmas)
oct1 = [ L(img1,sigma, sigma*sq2,ker_size=ker_size) for sigma in sigmas]
oct1 = array(oct1)
# Out:
# [ 1.          1.41421356  2.          2.82842712  4.        ]

# %%
imshow(oct1[3], cmap="gray")

# %%
def is_local_max(arr,i,j,k):
    is_max = 0
    is_min = 0
    for x in range(-1,2):
        for y in range(-1,2):
            for z in range(-1,2):
                if not ((x==0) and (y==0) and (z==0)):
                    if (arr[i,j,k] > arr[i+x,j+y,k+z]):
                        is_max += 1
                    else:
                        is_min += 1
    if is_max == 8 or is_min==8:
        return True

def find_local_max(arr):
    results = []
    for i in range(1,arr.shape[0]-1):
        for j in range(1,arr.shape[1]-1):
            for k in range(1,arr.shape[2]-1):
                if is_local_max(arr,i,j,k):
                    results.append((i,j,k)) 
    return results

# %%
fp = find_local_max(oct1)

# %%
len(fp)
# Out:
# 743

# %%
for i in range(oct1.shape[0]):
    figure()
    imshow(oct1[i,:,:]); colorbar();

# %%
#for i in arange(100,200,20):
#    plot(oct1[:,i,i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-a5e472036420> in <module>()
#       1 for i in arange(100,200,20):
# ----> 2     plot(oct1[:,i,i])
#
# IndexError: index 100 is out of bounds for axis 1 with size 95

# %%
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection

# %%
len(fp)
# Out:
# 743

# %%
patches = []

figure(figsize=(20,20))
#imshow(img1, cmap='gray',origin='lower')
imshow(oct1[0,:,:], cmap="gray")
for p in fp:
#    circle = mpatches.Circle((p[1],p[2]), p[0]*5,fill=False, edgecolor='b', alpha=0.3)
    plot(p[2],p[1],".")
#    patches.append(circle)
#collection = PatchCollection(patches)
#ax.add_collection(collection)

# %%
img1.shape
# Out:
# (75, 75)

# %%
oct1.shape
# Out:
# (5, 95, 95)

# %%
imshow(oct1[0,:,:], cmap="gray")

# %%
scipy.signal.convolve2d(f_x,f_x)

# %%
p1 = scipy.signal.convolve2d(f_y,scipy.signal.convolve2d(f_x, img1))

# %%
p2 = scipy.signal.convolve2d(scipy.signal.convolve2d(f_y,f_x), img1)

# %%
conv2 = scipy.signal.convolve2d
def all_derivs(img):
    f_x = array([[1,0,-1]])
    f_y = f_x.T
    
    p_x = conv2(f_x,img)
    p_y = conv2(f_y,img)
    
    p_xx = conv2(f_x,p_x)
    p_yy = conv2(f_y,p_y)
    
    p_xy = conv2(f_x,p_y)
    #p_yx = conv2(f_y,p_x)
    p_yx = p_xy
    
    return [[p_xx, p_xy],[p_yx,p_yy]]

# %%
#res = all_derivs(img1)

# %%
cur_oct = -1
cur_res = None
scores = []
for p in fp:
    if p[0] != cur_oct:
        print p[0]
        cur_oct = p[0]
        cur_res = all_derivs(oct1[cur_oct])
    tr  = cur_res[0][0][p[1],p[2]] + cur_res[1][1][p[1],p[2]]
    det = cur_res[0][0][p[1],p[2]]  * cur_res[1][1][p[1],p[2]] - cur_res[0][1][p[1],p[2]] ** 2
    #print det, tr
    score =  tr**2/det
    print score, score<12
    scores.append(score)
# Out:
# 1
# 86.1886410294
#  False
# 199.566924293 False
# -79.5287876138 True
# -48.2562813815 True
# 180.214603507 False
# 51.7625397137 False
# -1080.25551871 True
# -119.103906782 True
# -2554.34907232 True
# 60.5383603671 False
# 43.6267490612 False
# 88.6152580827 False
# -112.457208143 True
# -33.3495653943 True
# 72.6656559118 False
# 40.5090252347 False
# 16.1265068781 False
# 205.573090066 False
# -104.741797383 True
# 28.7162841939 False
# -13.4227884756 True
# 1508.825519 False
# 28.6897515186 False
# -60.6785869677 True
# -55.8560364555 True
# 30.2017546535 False
# 80.75438234 False
# 58.7658715896 False
# 80.3569748348 False
# 4.87312001357 True
# 4.37563287002 True
# -20.6066631664 True
# 29.1933553746 False
# 40.9494702484 False
# -10.9549687961 True
# 29.2554592521 False
# 9.82600363714 True
# -6.87513292378 True
# 7.16831702369 True
# 8.30240418543 True
# -0.919917110889 True
# 5.73689409094 True
# 9.93099531405 True
# 4.67960609303 True
# 5.55972406668 True
# -9.14084081775 True
# -0.0485978183732 True
# -0.987902398501 True
# 8.28516927303 True
# 8.54580987995 True
# -0.00925340154455 True
# -2.95428862916 True
# 6.03244206567 True
# 9.74925441676 True
# 11.1191235341 True
# -2.2610383592 True
# -0.373444761931 True
# -0.0673735946794 True
# -0.0512019494116 True
# -0.606323359085 True
# -0.593629606331 True
# -0.684296912974 True
# -25.8555961726 True
# 64.9228591894 False
# 4.57648271966 True
# 9.30475229921 True
# -0.0602252761358 True
# -2.2032677579 True
# 5.07933403935 True
# 7.06482771577 True
# 12.033015365 False
# 28.1045901152 False
# 99.0683496268 False
# -779.970763444 True
# 5.93952120776 True
# 9.60771528239 True
# -0.686689939847 True
# -1.97442091539 True
# -0.00111738042645 True
# 21.147365822 False
# -0.0491309802685 True
# -0.561763416349 True
# 72.3998825837 False
# 9.01581184821 True
# -0.0111941860016 True
# -0.434160855991 True
# -0.00698997884568 True
# -7.66292357252 True
# -4.22368743773e-05 True
# 6.56662384339 True
# -0.110999285971 True
# 30.1434627178 False
# -0.0656516489274 True
# -0.0752520771685 True
# -0.141145184305 True
# -0.80439987785 True
# 4.38497946849 True
# -7.78239248947 True
# 4.89770182905 True
# 4.25133386354 True
# 8.6416947451 True
# -1.69872177042 True
# 5.13892661446 True
# -2.51316890287 True
# -0.369826220009 True
# -2.9494278597 True
# -12.6505744805 True
# -1.55813979613 True
# -54.1614917966 True
# -1.73972293666 True
# 22.9721694987 False
# -0.734248174342 True
# -1.80460943275 True
# -1.81309402528 True
# 5.72708815768 True
# -1.5504855799 True
# 5.5975329538 True
# -0.385585314105 True
# -0.00412510576483 True
# -2.26924916351 True
# 14.9189102835 False
# -0.0472410279626 True
# -0.177753872868 True
# -12.0239391699 True
# -26.4731455075 True
# -7.0587616931 True
# -6.10436088853 True
# -4.76206034796 True
# -3.39679270371 True
# -0.448643775878 True
# -2.01311133496 True
# -0.217507595232 True
# -0.00601976093063 True
# 5.57779352217 True
# -2.49550966664 True
# -3.72210723847 True
# -4.44695216372 True
# -4.80851644399 True
# -0.342645123406 True
# 7.7096274698 True
# -4.88131030007 True
# -15.332112218 True
# -3.10985480096 True
# -6.02155913224 True
# -0.000233616159682 True
# -3.55370647214 True
# -3.96337253748 True
# -3.27763598823 True
# -0.313462234156 True
# -1.18470751217 True
# -0.0382508858778 True
# 4.3168602804 True
# -29.0656751453 True
# -0.153881687072 True
# -1.57233272931 True
# -0.0649277449596 True
# -0.656502400413 True
# 7.00283712411 True
# 4.07272139981 True
# 11.2011522358 True
# 9.28703778722 True
# 10.747797143 True
# 33.398054722 False
# -8.16004408313 True
# -1.19463094411 True
# 28.7341406771 False
# 4.15485800175 True
# -0.899683686157 True
# -1.68158572992 True
# -3.42925457518 True
# -0.0214969535019 True
# -2.03301166925 True
# -44.0122401536 True
# -35.6938668743 True

# %%
len(oct1)
# Out:
# 5

# %%
r=1.1
threshold = (r+1)**2/r
threshold = 1.2
print threshold
figure(figsize=(20,20))
#imshow(img1, cmap='gray',origin='lower')
imshow(oct1[0,:,:], cmap="gray")
i = 0

colors = ["","blue","yellow","green","orange"]
for p in fp:
#    circle = mpatches.Circle((p[1],p[2]), p[0]*5,fill=False, edgecolor='b', alpha=0.3)
    
    if (abs(scores[i])<threshold):
        plot(p[2],[1],".",color="white")
    else:
        #plot(p[2],p[1],".",color=colors[p[0]])
        pass
    i+=1
# Out:
# 1.2
